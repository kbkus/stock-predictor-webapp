# %% [markdown]
# # To do list

# %% [markdown]
# - [X] create virtual environment
# - [ ] import previous functions to collect data / train model
# - [X] install streamlit
# - [ ] test simple streamlit app
# - [ ] create a class to organize data processing?
